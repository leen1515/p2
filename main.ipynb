# %%
import pandas as pd

df_products = pd.read_csv("datas/datas_food.csv", sep='\t')
# Out:
# C:\Users\leven\AppData\Local\Temp\ipykernel_13460\311042690.py:3: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,35,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_products = pd.read_csv("datas/datas_food.csv", sep='\t')

# %% [markdown]
# Récupère un résumé des informations sur les données.

# %%
print("dataframe's info : ")
df_products.info()

print("null value's total :")
df_products.isnull().sum()
# Out:
# dataframe's info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Columns: 162 entries, code to water-hardness_100g
# dtypes: float64(106), object(56)
# memory usage: 396.5+ MB
# null value's total :
# code                           23
# url                            23
# creator                         2
# created_t                       3
# created_datetime                9
#                             ...
# carbon-footprint_100g      320504
# nutrition-score-fr_100g     99562
# nutrition-score-uk_100g     99562
# glycemic-index_100g        320772
# water-hardness_100g        320772
# Length: 162, dtype: int64

# %%
from functions_py.delete import delete_null_columns, delete_null_rows

df_product_treatment_columns = delete_null_columns(df_products)
df_products_without_null = delete_null_rows(df_product_treatment_columns)

# %%
from functions_py.percentage import calculate_and_display_percentages
from functions_py.visuel import display_null_percentage

null_percentage_df = calculate_and_display_percentages(df_products_without_null).to_frame().reset_index()
null_percentage_df.columns = ['Columns', 'Percentage of null values']
display_null_percentage(null_percentage_df)
# Out:
# c:\Users\leven\Desktop\openclassrooms\datascience\p2\p2\functions_py\visuel.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(
# c:\Users\leven\Desktop\openclassrooms\datascience\p2\p2\functions_py\visuel.py:14: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   barplot = sns.barplot(
